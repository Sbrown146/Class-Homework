# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
#N = 60
g1 = (0.6 + 0.6 * np.random.rand(N), np.random.rand(N))
g2 = (0.4+0.3 * np.random.rand(N), 0.5*np.random.rand(N))
g3 = (0.3*np.random.rand(N),0.3*np.random.rand(N))

data = (g1, g2, g3)
colors = ("red", "green", "blue")
groups = ("coffee", "tea", "water")

# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

for data, color, group in zip(data, colors, groups):
    x, y = data
    ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)

plt.title('Matplot scatter plot')
plt.legend(loc=2)
plt.show()
# Out:
# (array([0.87914498, 1.06521139, 1.03844182, 0.67112598, 0.64100396,
#        0.65101077, 1.1441142 , 1.1000576 , 1.0584852 , 1.05380213,
#        0.85066506, 0.78100752, 0.7190724 , 1.10463845, 0.98065295,
#        0.68681168, 0.94861723, 0.7713534 , 0.76435334, 0.77778224,
#        0.85764687, 0.74368672, 0.66388843, 1.02014168, 0.90805897,
#        0.974132  , 0.65742615, 0.60610689, 1.07622492, 1.18518646,
#        1.07482529, 1.09116785, 1.19018909, 0.87434833, 1.17782229,
#        1.10781044, 0.65238077, 0.99750216, 0.85528322, 0.6020104 ,
#        0.70993101, 0.75369242, 0.99305146, 0.77048558, 1.08481499,
#        1.11785693, 0.68621245, 1.00188794, 1.13520156, 0.84025198,
#        1.04075745, 0.81515638, 1.10242834, 0.68560534, 0.61271725,
#        0.68098924, 0.6997746 , 0.80521287, 1.11777315, 0.843445  ]), array([0.02970456, 0.42195871, 0.64939043, 0.10893626, 0.2311916 ,
#        0.93690572, 0.51682308, 0.5649902 , 0.88979972, 0.97929581,
#        0.90073682, 0.05153723, 0.45486553, 0.97263599, 0.14556438,
#        0.86252124, 0.68876596, 0.85823009, 0.0862666 , 0.85800571,
#        0.0804001 , 0.41735834, 0.6522119 , 0.58081338, 0.62501386,
#        0.93624053, 0.84113525, 0.44013366, 0.56357365, 0.99660953,
#        0.01779288, 0.5091861 , 0.67511863, 0.35988628, 0.20170469,
#        0.95863718, 0.69839437, 0.15144782, 0.63479003, 0.48357422,
#        0.78695471, 0.23303334, 0.9273149 , 0.66542498, 0.58919092,
#        0.00123889, 0.51788287, 0.6060769 , 0.87309986, 0.04038134,
#        0.21750515, 0.95118302, 0.53499876, 0.44939622, 0.87256779,
#        0.69378907, 0.68289356, 0.02488636, 0.92507657, 0.54958273]))
