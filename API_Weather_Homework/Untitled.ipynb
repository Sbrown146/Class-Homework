# %%
import requests
import json
import prettytable

#api key = 3c0da0ade9ce428ab0c069ebe36ceff8

headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['SUUR0000SAH'],\
                   "startyear":"2013", "endyear":"2014",\
                 "registrationkey": "3c0da0ade9ce428ab0c069ebe36ceff8", "catalog": "true",\
                 "calculations": "true", "annualaverage": "true"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)


for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
                if 'M01' <= period <= 'M12':
                    x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    
    #If you want the output as a text file.
    #output = open(seriesId + '.txt','w')
    #output.write (x.get_string())
    #output.close()
    
json_data
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 264,
#  'message': ['BLS does not produce net change calculations for Series SUUR0000SAH'],
#  'Results': {'series': [{'seriesID': 'SUUR0000SAH',
#     'catalog': {'series_title': 'Housing in U.S. city average, all urban consumers, chained, not seasonally adjusted',
#      'series_id': 'SUUR0000SAH',
#      'seasonality': 'Not Seasonally Adjusted',
#      'survey_name': 'Chained CPI-All Urban Consumers',
#      'survey_abbreviation': 'SU',
#      'measure_data_type': 'Housing',
#      'area': 'U.S. city average',
#      'item': 'Housing'},
#     'data': [{'year': '2014',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '138.762',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '-0.1', '6': '0.3', '12': '2.5'}}},
#      {'year': '2014',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '138.630',
# ...

# %%
json_data["Results"]["series"]
# Out:
# [{'seriesID': 'SUUR0000SAH',
#   'catalog': {'series_title': 'Housing in U.S. city average, all urban consumers, chained, not seasonally adjusted',
#    'series_id': 'SUUR0000SAH',
#    'seasonality': 'Not Seasonally Adjusted',
#    'survey_name': 'Chained CPI-All Urban Consumers',
#    'survey_abbreviation': 'SU',
#    'measure_data_type': 'Housing',
#    'area': 'U.S. city average',
#    'item': 'Housing'},
#   'data': [{'year': '2014',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '138.762',
#     'footnotes': [{}],
#     'calculations': {'net_changes': {},
#      'pct_changes': {'1': '0.1', '3': '-0.1', '6': '0.3', '12': '2.5'}}},
#    {'year': '2014',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '138.630',
#     'footnotes': [{}],
#     'calculations': {'net_changes': {},
#      'pct_changes': {'1': '-0.1', '3': '-0.1', '6': '0.6', '12': '2.6'}}},
#    {'year': '2014',
#     'period': 'M10',
#     'periodName': 'October',
# ...

# %%
# [0] removes brackets for further calls.
json_data["Results"]["series"][0]["data"]
# Out:
# [{'year': '2014',
#   'period': 'M12',
#   'periodName': 'December',
#   'value': '138.762',
#   'footnotes': [{}],
#   'calculations': {'net_changes': {},
#    'pct_changes': {'1': '0.1', '3': '-0.1', '6': '0.3', '12': '2.5'}}},
#  {'year': '2014',
#   'period': 'M11',
#   'periodName': 'November',
#   'value': '138.630',
#   'footnotes': [{}],
#   'calculations': {'net_changes': {},
#    'pct_changes': {'1': '-0.1', '3': '-0.1', '6': '0.6', '12': '2.6'}}},
#  {'year': '2014',
#   'period': 'M10',
#   'periodName': 'October',
#   'value': '138.746',
#   'footnotes': [{}],
#   'calculations': {'net_changes': {},
#    'pct_changes': {'1': '-0.1', '3': '0.0', '6': '1.2', '12': '2.7'}}},
#  {'year': '2014',
#   'period': 'M09',
#   'periodName': 'September',
#   'value': '138.849',
#   'footnotes': [{}],
#   'calculations': {'net_changes': {},
#    'pct_changes': {'1': '0.0', '3': '0.3', '6': '1.1', '12': '2.6'}}},
#  {'year': '2014',
#   'period': 'M08',
#   'periodName': 'August',
# ...

# %%
print(json_data["Results"]["series"][0]["data"][0:12][0]["period"])
print(json_data["Results"]["series"][0]["data"][0:12][0]["value"])

print(json_data["Results"]["series"][0]["data"][0:12][11]["period"])
print(json_data["Results"]["series"][0]["data"][0:12][11]["value"])
# Out:
# M12
# 138.762
# M01
# 136.203

# %%
# Everything for year 2014.
test = []

for row in json_data:
    test.append[json_data["Results"]["series"][0]["data"][0:12][row]["value"]]

#json_data["Results"]["series"][0]["data"][0:12][2]["value"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-37fd50ae2562> in <module>
#       3
#       4 for row in json_data:
# ----> 5     test.append[json_data["Results"]["series"][0]["data"][0:12][row]["value"]]
#       6
#       7 #json_data["Results"]["series"][0]["data"][0:12][2]["value"]
#
# TypeError: list indices must be integers or slices, not str
