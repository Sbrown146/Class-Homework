# %%
#Data Trends:
# 1) Temperature vs Latitude archs (expected)
# 2) Temperature vs Latitude archs around 20, not 0 (unexpected)
# 3) All other graphs are fairly random
# 4) Majority of humidity seems rather high.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from config import api_key
from citipy import citipy
import openweathermapy.core as owm
import csv
import os

settings={"units": "metric", "appid": api_key}

#Both work.
orlando_weather=owm.get_current("orlando", units="metric", appid=api_key)
current_weather_orlando=owm.get_current("orlando", **settings)
current_weather_orlando["coord"]["lat"]
# Out:
# 28.54

# %%
#Url to call city weather statistics.
url="http://api.openweathermap.org/data/2.5/weather?"
q_url=f'{url}appid={api_key}&units={"metric"}&q='

print(q_url)
print(q_url+"orlando")
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=289ec2a2f5f22432095c2b476bd08373&units=metric&q=
# http://api.openweathermap.org/data/2.5/weather?appid=289ec2a2f5f22432095c2b476bd08373&units=metric&q=orlando

# %%
#To get specific information from dictionary.
orlando_response=requests.get(q_url+"orlando")
orlando_json=orlando_response.json()

#Loop array append paths.
orlando_lat=orlando_json["coord"]["lat"]
orlando_temp=orlando_json["main"]["temp"]
orlando_h=orlando_json["main"]["humidity"]
orlando_clouds=orlando_json["clouds"]["all"]
orlando_wind=orlando_json["wind"]["speed"]
orlando_temp
# Out:
# 34.14

# %%
#Working loop
latitude_range=(-90,90)
longitude_range=(-180,180)

latitude_longitude=[]
cities=[]
city_test=["orlando", "jacksonville", "miami", "tampa", "kissimmee"]

#2000 takes 3 minutes to process.
#Use 1500 for final.  Takes WAY too long.  Think VBA length of time.
latitude=np.random.uniform(low=-90.000, high=90.000, size=2000)
longitude=np.random.uniform(low=-180.000, high=180.000, size=2000)
latitude_longitude=zip(latitude, longitude)

for x in latitude_longitude:
    city=citipy.nearest_city(x[0], x[1]).city_name
    
    if city not in cities:
        cities.append(city)
       
city_list=[]
city_latitude=[]
city_temperature=[]
city_humidity=[]
city_clouds=[]
city_wind=[]

for city in cities:
    try:
        city_list.append(city)
        current_weather=owm.get_current(city, units="metric", appid=api_key)
        city_latitude.append(current_weather["coord"]["lat"])
        city_temperature.append(current_weather["main"]["temp"])
        city_humidity.append(current_weather["main"]["humidity"])
        city_clouds.append(current_weather["clouds"]["all"])
        city_wind.append(current_weather["wind"]["speed"])
    except:
        city_list.remove(city)
        continue
        
    

print(len(cities))
print(len(city_list))
print(len(city_clouds))
# Out:
# 781
# 709
# 709

# %%
#Check list length

print(len(city_list))
print(len(city_latitude))
print(len(city_temperature))
print(len(city_humidity))
print(len(city_clouds))
print(len(city_wind))
# Out:
# 709
# 709
# 709
# 709
# 709
# 709

# %%
#Cap these at 100 since they are percentages.
for k in range(len(city_humidity)):
    if city_humidity[k]>100:
        city_humidity[k]=100


for m in range(len(city_clouds)):
        if city_clouds[m]>100:
            city_clouds[m]=100
        
print(max(city_humidity))
print(max(city_clouds))
# Out:
# 100
# 100

# %%
#Second loop test.  Save for error documentation.
city_latitude=[]
city_temperature=[]
city_humidity=[]
city_clouds=[]
city_wind=[]

for city in cities:
    current_weather=owm.get_current(city, units="metric", appid=api_key)
    city_latitude.append(current_weather["coord"]["lat"])
    city_temperature.append(current_weather["main"]["temp"])
    city_humidity.append(current_weather["main"]["humidity"])
    city_clouds.append(current_weather["clouds"]["all"])
    city_wind.append(current_weather["wind"]["speed"])
# Out:
# -------------------------------------------------------------------------
# HTTPError                               Traceback (most recent call last)
# <ipython-input-18-869f62222c62> in <module>
#       7
#       8 for city in cities:
# ----> 9     current_weather=owm.get_current(city, units="metric", appid=api_key)
#      10     city_latitude.append(current_weather["coord"]["lat"])
#      11     city_temperature.append(current_weather["main"]["temp"])
#
# ~\Anaconda3\lib\site-packages\openweathermapy\core.py in get_current(city, **params)
#     153            >>> data = get_current(zip="34128,DE")
#     154 	"""
# --> 155         data = wrap_get("weather")(city, **params)
#     156         return DataPoint(data)
#     157
#
# ~\Anaconda3\lib\site-packages\openweathermapy\core.py in call(loc, **params)
#      97                 if settings:
#      98                         params.update(settings)
# ---> 99                 data = get(url, **params)
#     100                 if converter:
#     101                         data = converter(data)
#
# ~\Anaconda3\lib\site-packages\openweathermapy\core.py in get(url, **params)
#      60 def get(url, **params):
#      61         """Return data as (nested) dictionary for ``url`` request."""
# ---> 62         data = utils.get_url_response(url, **params)
#      63         # Decoding: Python3 compatibility
#      64         return json.loads(data.decode("utf-8"))
#
# ~\Anaconda3\lib\site-packages\openweathermapy\utils.py in get_url_response(url, **params)
#      29         if params:
#      30                 url = url+"?"+urlencode(params)
# ---> 31         response = urlopen(url)
#      32         data = response.read()
#      33         response.close()
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
#Save citys as csv

city_zip=zip(city_list)

with open(os.path.join("city_list.csv"), "w", newline="") as city_csv:
    writer=csv.writer(city_csv)

    writer.writerow(["City Name"])

    writer.writerows(city_zip)

# %%
#print(city_response["coord"]["lat"])
#Formatting temp was causing each point to be displayed on the y axis, unsorted.
#Removing the formatting fixed issues with the y axis.
#Change wind speed from meters per second to mph.

weather_almanac={
            "City": city_list, "Latitude": city_latitude,
            "Temperature (F)": city_temperature, "Humidity (%)": city_humidity,
            "Cloudiness (%)": city_clouds, "Wind Speed (mph)": city_wind
            }



weather_df=pd.DataFrame(weather_almanac)
weather_df=weather_df.set_index("City")
weather_df["Temperature (F)"]=round(((9/5)*(weather_df["Temperature (F)"]) + 32), 2)
weather_df["Wind Speed (mph)"]=round((weather_df["Wind Speed (mph)"]*(3600/1609.344)), 2)
weather_df.head()
# Out:
#                  Latitude  Temperature (F)  Humidity (%)  Cloudiness (%)  \
# City
# hermanus           -34.42            56.21            66              47
# mataura            -46.19            41.00            90               0
# puerto ayora        -0.74            76.08            65              20
# bambous virieux    -20.34            68.29            77              40
# ponta do sol       -20.63            65.41            55              66
#
#                  Wind Speed (mph)
# City
# hermanus                    14.00
# mataura                      1.01
# puerto ayora                19.46
# bambous virieux             11.41
# ponta do sol                 0.63

# %%
#Temp scatter plot.

plt.title("City Latitude vs Max Temperature (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")


plt.scatter( \
    weather_df["Latitude"], weather_df["Temperature (F)"], edgecolor="black",  \
    alpha=.75, linewidth=1, marker="o"
    )



plt.grid()
plt.savefig("Latitude vs Max Temperature (F).png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Humidity scatter plot.
#Try out normality tests - k1, p1 = stats.normaltest(sales_df1)

print(weather_df["Humidity (%)"].mean())

plt.title("City Latitude vs Humidity (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")


plt.scatter( \
    weather_df["Latitude"], weather_df["Humidity (%)"], edgecolor="black",  \
    alpha=.75, linewidth=1, marker="o"
    )



plt.grid()
plt.savefig("Humidity vs Max Temperature (F).png")
plt.show
# Out:
# 69.38081805359661
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Cloud scatter plot.

plt.title("City Latitude vs Cloudiness (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")


plt.scatter( \
    weather_df["Latitude"], weather_df["Cloudiness (%)"], edgecolor="black",  \
    alpha=.75, linewidth=1, marker="o"
    )



plt.grid()
plt.savefig("Latitude vs Cloudiness (%).png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Wind speed scatter plot.

plt.title("City Latitude vs Wind Speed (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")


plt.scatter( \
    weather_df["Latitude"], weather_df["Wind Speed (mph)"], edgecolor="black",  \
    alpha=.75, linewidth=1, marker="o"
    )



plt.grid()
plt.savefig("Latitude vs Wind Speed (mph).png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
